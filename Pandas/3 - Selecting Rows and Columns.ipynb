# %%
import numpy as np
import pandas as pd
X = pd.read_csv('../datasets/data_2d.csv', header=None)

# %%
# Dataframes do not act the same as numpy arrays
X[0,0]  # numpy syntax
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\InsaneMosquito\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4363)()
#
# KeyError: (0, 0)
#
# ...

# %%
# Convert to an array
M = X.as_matrix() # poorly named
type(M)
# Out:
# numpy.ndarray

# %%
# Get single series in dataframe - A column
X[0]
# Out:
# 0     17.930201
# 1     97.144697
# 2     81.775901
# 3     55.854342
# 4     49.366550
# 5      3.192702
# 6     49.200784
# 7     21.882804
# 8     79.509863
# 9     88.153887
# 10    60.743854
# 11    67.415582
# 12    48.318116
# 13    28.829972
# 14    43.853743
# 15    25.313694
# 16    10.807727
# 17    98.365746
# 18    29.146910
# 19    65.100302
# 20    24.644113
# 21    37.559805
# 22    88.164506
# 23    13.834621
# 24    64.410844
# 25    68.925992
# 26    39.488442
# 27    52.463178
# 28    48.484787
# 29     8.062088
#         ...
# 70    30.187692
# 71    11.788418
# 72    18.292424
# 73    96.712668
# 74    31.012739
# 75    11.397261
# 76    17.392556
# 77    72.182694
# 78    73.980021
# 79    94.493058
# 80    84.562821
# 81    51.742474
# 82    53.748590
# 83    85.050835
# 84    46.777250
# 85    49.758434
# 86    24.119257
# 87    27.201576
# 88     7.009596
# 89    97.646950
# 90     1.382983
# 91    22.323530
# 92    45.045406
# 93    40.163991
# ...

# %% [markdown]
# ## Important Distinction between Pandas and Numpy
#
# - Numpy: `X[0]` -> Returns 0th row
# - Pandas: `X[0]` -> Returns column that has name `0`

# %%
# How to get a row in pandas
X.iloc[0]
# Out:
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
X.ix[0]
# Out:
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
# Select multiple columns 
X[[0,2]]
# Out:
#             0           2
# 0   17.930201  320.259530
# 1   97.144697  404.634472
# 2   81.775901  181.485108
# 3   55.854342  321.773638
# 4   49.366550  322.465486
# 5    3.192702   94.618811
# 6   49.200784  356.348093
# 7   21.882804  181.653769
# 8   79.509863  423.557743
# 9   88.153887  369.229245
# 10  60.743854  427.605804
# 11  67.415582  292.471822
# 12  48.318116  395.529811
# 13  28.829972  319.031348
# 14  43.853743  287.428144
# 15  25.313694  292.768909
# 16  10.807727  159.663308
# 17  98.365746  438.798964
# 18  29.146910  250.986309
# 19  65.100302  231.711508
# 20  24.644113  163.398161
# 21  37.559805   83.480155
# 22  88.164506  466.265806
# 23  13.834621  100.886430
# 24  64.410844  365.641048
# 25  68.925992  426.140015
# 26  39.488442  235.532389
# 27  52.463178  283.291640
# 28  48.484787  298.581440
# 29   8.062088  309.234109
# ..        ...         ...
# 70  30.187692   89.539008
# 71  11.788418  181.550683
# 72  18.292424  224.773383
# ...

# %%
# Select all rows where 0th column is < 5
X[X[0] < 5]
# Out:
#            0          1           2
# 5   3.192702  29.256299   94.618811
# 44  3.593966  96.252217  293.237183
# 54  4.593463  46.335932  145.818745
# 90  1.382983  84.944087  252.905653
# 99  4.142669  52.254726  168.034401
