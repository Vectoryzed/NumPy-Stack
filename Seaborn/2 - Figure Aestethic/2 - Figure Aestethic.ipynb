# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb

def sinplot(flip = 1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5): 
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
    
    
sinplot()
plt.show()

# %%
sb.set()
sinplot()
plt.show()

# %%
sb.set_style("white")
sinplot()
sb.despine() # removes top and right axis spines
plt.show()

# %%
sb.set_style("darkgrid", {'axes.axisbelow': False}) # set the axis style
sinplot()
sb.despine()
plt.show()
